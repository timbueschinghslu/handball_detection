# %% [markdown]
# Top-left: [265, 275]
# Top-right: [910, 260]
# Bottom-left: [110, 1035]
# Bottom-right: [1640, 915]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the pixel vertices
pixel_vertices = np.array([[1325, 1500], #bottom left
                           [1325, 550], #top left
                           [2300, 550], #top right
                           [2500, 1500]]) #bottom right

# Load your image (replace 'your_image.png' with your actual image file)
image = plt.imread('pixelvert_2.png')

# Plot the image
plt.imshow(image)

# Plot the vertices
for vertex in pixel_vertices:
    plt.plot(vertex[0], vertex[1], 'ro')  # 'ro' means red color, circle marker

# Optionally, connect the vertices to form a shape
plt.plot(*zip(*np.vstack([pixel_vertices, pixel_vertices[0]])), 'r-')  # 'r-' means red color, solid line

# Show the plot
plt.show()
